# %%
# 读取Delta Gold报表

df_gold_table = spark.read.format("delta") \
    .load("/Volumes/dbacademy/streaming/vol_yuto_stream_source/gold_realtime_minute_dashboard") \

# %%
# 正序排开

df_gold_table.sort("window_start","client_id").show(truncate=False)
